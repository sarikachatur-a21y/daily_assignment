# %% [markdown]
# 1. Write a program to create a text file and store the name, age, and marks of a student in it.

# %%
with open("studntdata.txt","a") as file:
    file.write("sarthak is learning python\n")
    file.write("age\n")
    file.write("marks\n")

# %% [markdown]
# 2. Write a program to read the complete contents of a file and count the total number of characters.

# %%
with open("studntdata.txt","r")as file:
    data= file.read()
    count=len(data)
    print(count)
# Out:
# 123

# %% [markdown]
# 3. Write a program to read a file line by line and count the total number of lines.

# %%
with open("studntdata.txt", "r") as file:
    count = 0
    for line in file:
        count += 1
    print(count)
# Out:
# 3

# %% [markdown]
# 4. Write a program to read a file and count the number of words present in it.

# %%
with open("studntdata.txt", "r") as file:
    data = file.read()
    words = data.split()
    print(len(words))
# Out:
# 6

# %% [markdown]
# 5. Write a program to copy the contents of one text file into another file.

# %%
with open("studntdata.txt","r") as file:
    data = file.read()
    
with open("studntdata_copy.txt","w") as file:
    file.write(data)

# %% [markdown]
# 6. Write a program to read a file and create another file containing only the lines that contain the word "Python".

# %%
with open("studntdata.txt", "r") as file:
    with open("studntdata_python.txt", "w") as newfile:
        for line in file:
            if "python" in line.lower():
                newfile.write(line)

# %% [markdown]
# 7. Write a program to append new student records to an existing file without deleting the previous records.

# %%
with open("studntdata.txt","a")as file:
    file.write("sarika\n")
    file.write("marks\n")

# %% [markdown]
# 8. Write a program to read a file and find the longest word present in it.

# %%
with open("studntdata.txt","r")as file:
    data=file.read()
    
words=data.split()
longest=""
for i in words:
     if len(i) > len(longest):
        longest=i

print(longest)
# Out:
# learning

# %% [markdown]
# 9. Write a program to read a file containing numbers and calculate their sum, average, maximum, and minimum.

# %%
with open("calculate.txt", "w") as file:
    file.write("10 20 30 40 50")
with open("calculate.txt", "r") as file:
    data = file.read()
numbers = []
for i in data.split():
    numbers.append(int(i))
print("Sum of numbers:", sum(numbers))
print("Average of numbers:", sum(numbers) / len(numbers))
print("Maximum of numbers:", max(numbers))
print("Minimum of numbers:", min(numbers))
# Out:
# Sum of numbers: 150
# Average of numbers: 30.0
# Maximum of numbers: 50
# Minimum of numbers: 10
