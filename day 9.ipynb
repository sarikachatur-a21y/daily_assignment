# %%
30/7/2026
COMPREHENSIONS

# %%
listone =[1,2,3,4,5,6,7,8]
listtwo =[]
for i in listone:
    
    listtwo.append(i**2)
    print(listone)
    print(listtwo)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4, 9]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4, 9, 16]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4, 9, 16, 25]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4, 9, 16, 25, 36]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4, 9, 16, 25, 36, 49]
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
#using comprehension
listone =[1,2,3,4,5,6,7,8]
#[expresion,itreate,condition(optional)
listtwo==[i**2 for  i in listone  if i%2==0]
print(listone)
print(listtwo)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
# [1, 4, 9, 16, 25, 36, 49, 64]

# %% [markdown]
# #[expresion,itreate,condition(optional)]
# third   ,first      ,two
# #list comprension use-[]
# listone =[1,2,3,4,5,6]
# listtwo =[i/2 for i in listone if i%2==0]
# print(listone)
# print(listtwo)

# %%
setone=(1,2,3,4,5,6,7,8,9)
settwo={ i**2 for i  in setone}
print(setone)
print (settwo)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)
# {64, 1, 4, 36, 9, 16, 49, 81, 25}

# %%
listone =["mohit","rohit","ram","sham"]
dictone = { i :len(i) for i in listone}
#{key:value}store
print(dictone)
# Out:
# {'mohit': 5, 'rohit': 5, 'ram': 3, 'sham': 4}

# %%
listone =[1,2,3,4,5,6]
#{1:1,2:4,3,4,5,6,7,8}
dicttwo =(i:i***3 for i in listone)
print(dicttwo)
# Out:
#   Cell In[16], line 3
#     dicttwo =(i:i***3 for i in listone)
#                ^
# SyntaxError: invalid syntax
