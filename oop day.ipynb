# %%
#12/08/2026
# object oriented programing

# %%
def greet():
 print("hello")
 greet()

# %%
class car:
    def greet():
        print("hello")
        obj1=car
        obj.greet()

# %%
class car:
    def_init_(self,name,color,price,milage):
        self.name ="demo"
        self.color="red"
        self.price="34"
        self.milage=20
    def display_infos(elf)
        print(self.name)
        print(self.color)
        print(self.price)
        prit(self.milage)
    #obj1 =car("nexon","white","101",25)
    obj1=car()
    object.display_info()

# %%
listone=[10,12,13]
listtwo=[14,15]
listthree=listone+listtwo
if len(list)%2==1:
middle =len(list)//2
print(list[middle])
else:
    middle=(lenlist)/2
    front=middle+1
    median=(list[middle]+list[front])/2
    print(median)
# Out:
#   Cell In[1], line 5
#     middle =len(list)//2
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
listone = [10, 12, 20]
listtwo = [14, 15,18]
listthree = listone + listtwo
if len(listthree) % 2 == 1:
    middle = len(listthree) // 2
    print("Median:", listthree[middle])
else:
    middle = len(listthree) // 2
    front = middle - 1
    median = (listthree[middle] + listthree[front]) / 2
    print("Median:", median)
# Out:
# Median: 17.0
