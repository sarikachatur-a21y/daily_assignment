# %% [markdown]
# 1. Student Information System
# Create a Student class with:
# • name
# • roll_no
# • branch
# • marks
# Create 3 student objects and create a method display() to print their details

# %%
class Student:
    def __init__(self, name, roll_no, branch, marks):
        self.name = name
        self.roll_no = roll_no
        self.branch = branch
        self.marks = marks
    def display(self):
        print("Name:", self.name)
        print("Roll No:", self.roll_no)
        print("Branch:", self.branch)
        print("Marks:", self.marks)
        print("--------------------")
student1 = Student("mitali", 11, "Computer Science", 85)
student2 = Student("Priya", 12, "Information Technology", 90)
student3 = Student("anita", 13, "Computer Science", 78)
student1.display()
student2.display()
student3.display()
# Out:
# Name: mitali
# Roll No: 11
# Branch: Computer Science
# Marks: 85
# --------------------
# Name: Priya
# Roll No: 12
# Branch: Information Technology
# Marks: 90
# --------------------
# Name: anita
# Roll No: 13
# Branch: Computer Science
# Marks: 78
# --------------------

# %% [markdown]
# 2. Employee Salary
# Create an Employee class with:
# • name
# • employee_id
# • salary
# Create a method display_salary() that displays the employee's salary.
# Create 3 employee objects.
# : Don't assign the values directly inside the class. Pass them while creating objects.

# %%
class Employee:
    def __init__(self, name, employee_id, salary):
        self.name = name
        self.employee_id = employee_id
        self.salary = salary

    def display_salary(self):
        print("Employee Name:", self.name)
        print("Employee ID:", self.employee_id)
        print("Salary:", self.salary)
        print("--------------------")
employee1 = Employee("Sarika", 101, 35000)
employee2 = Employee("nikita", 102, 45000)
employee3 = Employee("shruti", 103, 34000)
employee1.display_salary()
employee2.display_salary()
employee3.display_salary()
# Out:
# Employee Name: Sarika
# Employee ID: 101
# Salary: 35000
# --------------------
# Employee Name: nikita
# Employee ID: 102
# Salary: 45000
# --------------------
# Employee Name: shruti
# Employee ID: 103
# Salary: 34000
# --------------------

# %% [markdown]
# 3. Mobile Phone
# Create a Mobile class with:
# • brand
# • model
# • price
# Create a method:
# display_details()
# Create 3 mobile objects with different information.
# Expected concept: Constructor + objects.

# %%
class Mobile:

    def __init__(self, brand, model, price):
        self.brand = brand
        self.model = model
        self.price = price
    def display_details(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Price:", self.price)
        print("......")
mobile1 = Mobile("Apple", "iPhone 15", 70000)
mobile2 = Mobile("Samsung", "Galaxy S24", 65000)
mobile3 = Mobile("OnePlus", "OnePlus 12", 55000)
mobile1.display_details()
mobile2.display_details()
mobile3.display_details()
# Out:
# Brand: Apple
# Model: iPhone 15
# Price: 70000
# ......
# Brand: Samsung
# Model: Galaxy S24
# Price: 65000
# ......
# Brand: OnePlus
# Model: OnePlus 12
# Price: 55000
# ......
