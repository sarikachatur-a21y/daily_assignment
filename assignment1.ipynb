# %%
#Q1)Write a Python program to store the following information using variables and display it in awell-formatted way.
#Name,age,college name,city,course name
name = "Sarika"
age = 21
college_name = "GMD College"
city = "Wavi"
course_name = "B.Sc. Computer Science"
print("========== PERSONAL PROFILE ==========")
print("Name          :", name)
print("Age           :", age)
print("College Name  :", college_name)
print("City          :", city)
# Out:
# ========== PERSONAL PROFILE ==========
# Name          : Sarika
# Age           : 21
# College Name  : GMD College
# City          : Wavi

# %%
#Q2)Create variables for the following student details and print them:
# Student Name
# Roll Number
# Branch
#Percentage
# Passed (True/False)
 # Student Report

stud_name = "Sarika"
student_rollno = 1
branch = "Computer Science"
percentage = 81
passed = True
print("Stud Name        :", stud_name)
print("Student Roll No  :", student_rollno)
print("Branch           :", branch)
print("Percentage       :", percentage)
print("Passed           :", passed)
# Out:
# Stud Name        : Sarika
# Student Roll No  : 1
# Branch           : Computer Science
# Percentage       : 81
# Passed           : True

# %%
#Q3)Create 10 valid identifiers related to a college management system
# (for example:student_name, roll_no, etc.) 
# and assign appropriate values to them.Then print all the variables.
# 10 Valid Identifiers
student_name = "Sarika"
roll_no = 101
college_name = "G.M.D College"
course_name = "B.Sc. Computer Science"
department = "Computer Science"
semester = 6
attendance = 80
marks = 450
grade = "A"
is_passed = True
print(student_name)
print(roll_no)
print(college_name)
print(course_name)
print(department)
print(semester)
print(attendance)
print(marks)
print(grade)
print(is_passed)
# Out:
# Sarika
# 101
# G.M.D College
# B.Sc. Computer Science
# Computer Science
# 6
# 80
# 450
# A
# True

# %%
#Q4.) Comments Practice Write a Python program that contains:
# • At least 3 single-line comments  • 1 multi-line comment
# • A program that prints a short introduction about yourself
"""    #This is a multi-line comment.
"""

print("My name is Sarika sunil chatur.")# my name
print("I live in Pune(chikhali).")# city
print("I am studying B.Sc. Computer Science.")#education
print("I want to become an AI(artificail inteligence) Engineer.") #my course
# Out:
# My name is Sarika sunil chatur.
# I live in Pune(chikhali).
# I am studying B.Sc. Computer Science.
# I want to become an AI(artificail inteligence) Engineer.

# %%
#Q5)Rewrite the following invalid variable names into valid Python identifiers and assignappropriate values to them.
# 2student
# student-name
# student name
#class
#for
# employee@id
# Correct Variable Names

student_2 = "nikita"
student_name = "priya"
student_name1 = "supriya"
class_name = "(tybsc( computer scince))"
for_loop = 7
employee_id = 201
print(student_2)
print(student_name)
print(student_name1)
print(class_name)
print(for_loop)
print(employee_id)
# Out:
# nikita
# priya
# supriya
# (tybsc( computer scince))
# 7
# 201
