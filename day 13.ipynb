# %%
#10/08/2026

#paython namespace

# %%
# type of namespace
#1)global namespace
name="mohit"  #global namespace
age=23        #global namespace
def temp():
   rollno=56
   mark =75
   print(name)
   print(age)
   print(rollno)
   print(mark)
   temp()

# %%
#local namespace (funcation define)
def temp():
    username ="mohit"
    age=27
    print(username)
    print (age)
temp()
# Out:
# mohit
# 27

# %%
#enclosing name space
student_name ="demouser" #global
def one():       #enclosing namespace
    student_age=22
    print(student_roll)
    def two():        # local namespace
        student_roll=55
        print(student_roll)
        prin(student_age)
        print(student_name)
        
        two()
    one()

# %%
name ="demouser"
length =len(name)
print(length)
# Out:
# 8

# %%
#shado
name="mmohit"

def temp():
    
    name="demo"   #shadowing
    print(name)
    
    
    temp() 
    
    print(name)

# %%
#LEGB
name="demo"

    def one(): 
     name="dedmo1"
     print(name)
     
     
        def two():
         name="demo2"
         print(name)
         
         
        two()
          print(name)
    
    
     one():
     print(name)
# Out:
#   Cell In[7], line 4
#     def one():
#     ^
# IndentationError: unexpected indent
