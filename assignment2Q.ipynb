# %%
#Q5
units = int(input("Enter units consumed: "))
cost = float(input("Enter cost per unit: "))

bill = units * cost
gst = bill * 0.18
total = bill + gst

print("Bill =", bill)
print("GST (18%) =", gst)
print("Total Bill =", total)

# %%
#Q1) Create variables of all Python primitive data types. Print their: 
# • Value  
# • Data Type  
# • Memory Address (id()) 
num = 100   # Integer
price = 99.99 # Float
comp = 3 + 4j  #complex
is_passed = True  # Boolean
name = "Sarika"   #string
value = None   #none type

# %%
#Q2Create three variables - a = 15 - b = 4 
# • Addition 
# • Subtraction  
# • Multiplication  
# • Division  • Floor Division  • Modulus  
# • Exponent 
a = 15
b = 4
# Arithmetic Operations
addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b
floor_division = a // b
modulus = a % b
exponent = a ** b
# results
print("a =", a)
print("b =", b)
print("Addition =", addition)
print("Subtraction =", subtraction)
print("Multiplication =", multiplication)
print("Division =", division)
print("Floor Division =", floor_division)
print("Modulus =", modulus)
print("Exponent =", exponent)
# Out:
# a = 15
# b = 4
# Addition = 19
# Subtraction = 11
# Multiplication = 60
# Division = 3.75
# Floor Division = 3
# Modulus = 3
# Exponent = 50625

# %%
#Q3)Create two variables: - x = "100" - y = 50 
# • Convert the variables so that you can perform arithmetic operations between them. 
# # Create variables
y = 100
z = 56
y = float(y) #boolean
z = float(z)
print("y =", y)# Perform arithmetic operations
print("z =", z)
print("Addition =", y + z)
print("Subtraction =", y - z)
print("Multiplication =", y * z)
print("Division =", y/z)
# Out:
# y = 100.0
# z = 50.0
# Addition = 150.0
# Subtraction = 50.0
# Multiplication = 5000.0
# Division = 2.0

# %%
#Q4) Predict the output before running the program, then verify.
# a = 10 
# b = 20
# print(a + b * 2) 
# print((a + b) * 2) 
# print(a ** 2 + b) 
# print(a // 3) 
# print(a / 3) 
a =10
b =20
print(a+b*2)
print((a+b)*2)
print(a**2+b)
print(a//3)
print(a/3)
# Out:
# 50
# 60
# 120
# 3
# 3.3333333333333335

# %%
#Q5. Write a program to calculate electricity bill. Use variables for:
# • Units Consumed 
# • Cost per Unit 
# • Calculate total bill and GST (18%). 
units = int(input("Enter units consumed: "))
cost = float(input("Enter cost per unit: "))

bill = units * cost
gst = bill * 0.18
total = bill + gst

print("Bill =", bill)
print("GST (18%) =", gst)
print("Total Bill =", total)
# Out:
# Bill = 16.0
# GST (18%) = 2.88
# Total Bill = 18.88

# %%
#Q6. Create a list of programming languages. 
# - Check whether: 
# • "Python" exists. 
# • "Java" does not exist.  • "C++" exists.
# • Use Membership Operators. 
languages = ["Python", "C", "C++", "JavaScript"]
print("Python" in languages)    
print("Java" not in languages)  
print("C++" in languages)
# Out:
# True
# True
# True

# %%
#Q7Write a program that converts: 
# •  int → float  
# •  float → string 
# •  string → int 
# •  int → bool  
# •  bool → int 

a = 10
print(float(a)) #int to float
b = 12.5
print(str(b)) #float to string
c = "100"
print(int(c))#string to int
d = 1
print(bool(d)) #int to boolean
e = True
print(int(e))#bool to int
# Out:
# 10.0
# 12.5
# 100
# True
# 1

# %%
#Q8 . Predict the output.
# a = 10
# a += 5 
# a *= 2
# a -= 8 
# a /= 4 print(a) 
a = 10
a += 5
a *= 2
a -= 8
a /= 4
print(a)
# Out:
# 5.5

# %%
#Q9  Predict the output.
# print(5 == 5.0)
# print(5 is 5.0) 
print(5 == 5.0)
print(5 is 5.0)

# %%
#Q10)Create a program that stores product information. 
# Store: • Product Name 
#  Price 
#  Quantity  Calculate: 
#  Total Cost  
#  GST (18%)  
#  Final Amount 

product_name = notebook
price = 40
quantity = 5
total_cost= 200
gst = total_cost * gst
final_amount= total_cost + gst
print("\nProduct Name:", product_name)
print("\nPrice:", price)
print("Total Cost:", total_cost)
print("GST (18%):", gst)
print("Final Amount:", final_amount)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #Q10)
# ----> 2 product_name = pen
#       3 price = 40
#       4 quantity = 5
#       5 total_cost= 200
#
# NameError: name 'pen' is not defined

# %%
#Q11). Write a program that checks whether a person can register for a driving license. Conditions: • Age ≥ 18  • Indian Citizen 
age = 24
citizen = True
if age >= 18 and citizen:
 print("Eligible for Driving License")
else:
print("Not Eligible")
# Out:
# Eligible for Driving License

# %%
#Q12 2. Predict the output. a = [10,20]
# b = a
# c = [10,20] 
# print(a == b)
# print(a is b)
# print(a == c) 
# print(a is c) 
# print(id(a))
# print(id(b)) 
# print(id(c)) 
a = [10, 20]
b = a
c = [10, 20]
print(a == b)
print(a is b)
print(a == c)
print(a is c)
print(id(a))
print(id(b))
print(id(c))
# Out:
# True
# True
# True
# False
# 1628700908864
# 1628700908864
# 1628701084416
